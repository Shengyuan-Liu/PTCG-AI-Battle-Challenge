# %%
import json

path = "replay\\81729405.json"

# %%
with open(path, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
data
# Out:
# {'configuration': {'actTimeout': 0,
#   'episodeSteps': 10000,
#   'runTimeout': 2000,
#   'seed': 710775267},
#  'description': 'Limited Card Battle.',
#  'id': '1d393c86-7029-11f1-8aad-0242ac130202',
#  'info': {'Agents': [{'Name': 'Ohashi', 'ThumbnailUrl': None},
#    {'Name': 'Ioannis M', 'ThumbnailUrl': None}],
#   'EpisodeId': 81729405,
#   'LiveVideoPath': None,
#   'TeamNames': ['Ohashi', 'Ioannis M']},
#  'module_version': '1.30.1',
#  'name': 'cabt',
#  'rewards': [-1, 1],
#  'schema_version': 1,
#  'specification': {'action': {'default': [],
#    'description': 'List of option index.',
#    'type': 'array'},
#   'agents': [2],
#   'configuration': {'actTimeout': {'default': 0,
#     'description': 'Maximum runtime (seconds) to obtain an action from an agent.',
#     'minimum': 0,
#     'type': 'number'},
#    'episodeSteps': {'default': 10000,
#     'description': 'Maximum number of steps in the episode.',
#     'minimum': 1,
#     'type': 'integer'},
# ...
